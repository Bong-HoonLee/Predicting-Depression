# %%
import pandas as pd

df_origin = pd.read_csv('../data/HN_cardinal_1_8.csv')

# %%
target_4_8 = [
	"cfam",
	"house",
	"live_t",
	"ainc",
	"sex",
	"age",
	"marri_1",
	"marri_2",
	"tins",
	"npins",
	"D_1_1",
	"D_2_1",
	"D_2_wk",
	"DI1_dg",
	"DI1_ag",
	"DI1_pr",
	"DI1_pt",
	"DI1_2",
	"DI2_dg",
	"DI2_ag",
	"DI2_pr",
	"DI2_pt",
	"DI2_2",
	"DI3_dg",
	"DI3_ag",
	"DI3_pr",
	"DI3_pt",
	"DI3_2",
	"DJ4_dg",
	"DJ4_ag",
	"DJ4_pr",
	"DJ4_pt",
	"DJ4_3",
	"DE1_dg",
	"DE1_ag",
	"DE1_pr",
	"DE1_pt",
	"DE1_3",
	"BH9_11",
	"BH1",
	"BH2_61",
	"LQ4_00",
	"LQ4_01",
	"LQ4_02",
	"LQ4_03",
	"LQ4_04",
	"LQ4_05",
	"LQ4_06",
	"LQ4_07",
	"LQ4_08",
	"LQ4_09",
	"LQ4_10",
	"LQ4_11",
	"LQ4_12",
	"LQ4_13",
	"LQ4_14",
	"LQ4_15",
	"LQ4_16",
	"LQ4_21",
	"LQ4_22",
	"LQ4_23",
	"LQ4_24",
	"LQ4_25",
	"LQ4_26",
	"LQ4_27",
	"LQ4_28",
	"LQ4_29",
	"LQ1_sb",
	"LQ1_mn",
	"LQ2_ab",
	"LQ2_mn",
	"MH1_yr",
	"MH1_1",
	"MO1_wk",
	"MO1_1",
	"educ",
	"graduat",
	"EC1_1",
	"EC_occp",
	"EC_stt_1",
	"EC_lgw_2",
	"EC_lgw_4",
	"EC_wht_23",
	"EC_wht_5",
	"EC_pedu_1",
	"EC_pedu_2",
	"BO1",
	"BO1_1",
	"BO1_2",
	"BO1_3",
	"BO2_1",
	"BD1",
	"BD2",
	"BD1_11",
	"BD2_1",
	"BD2_31",
	"BD2_32",
	"BA2_12",
	"BA2_14",
	"BA2_2_1",
	"BA2_2_2",
	"BA2_2_3",
	"BA2_2_4",
	"BA2_2_5",
	"BA2_2_6",
	"BA2_22",

	"BS1_1",
	"BS3_1",
	"BS3_2",
	"BS6_2",
	"BS6_3",
	"BS5",
	"BS5_1",
	"BS8_2",
	"BS9_2",
	"BE3_31",
	"BE5_1",
	"LW_ms",
	"LW_ms_a",
	"LW_mp_a",
	"LW_pr",
	"LW_br",
	"LW_pr_1",
	"LW_mt_a1",
	"LW_mt_a2",
	"LW_oc",
	"BM1_0",
	"BM1_1",
	"BM1_2",
	"BM1_3",
	"BM1_4",
	"BM1_5",
	"BM1_6",
	"BM1_7",
	"BM1_8",
	"BM2_1",
	"BM2_2",
	"BM2_3",
	"BM2_4",
	"BM2_5",
	"BM7",
	"BM8",
	"MO4_00",
	"OR1_2",
	"BM14",
	"BM14_1",
	"HE_rPLS",
	"HE_PLS_15",
	"HE_PLS_30",
	"HE_mPLS",
	"HE_sbp1",
	"HE_sbp2",
	"HE_sbp3",
	"HE_sbp",
	"HE_dbp1",
	"HE_dbp2",
	"HE_dbp3",
	"HE_dbp",
	"HE_ht",
	"HE_wt",
	"HE_wc",
	"HE_BMI",
	"HE_obe",
	"HE_chol",
	"HE_HDL_st2",
	"HE_TG",
	"HE_LDL_drct",
	"HE_HCHOL",
	"HE_HTG",
	"HE_glu",
	"HE_HbA1c",
	"HE_DM_HbA1c",
	"HE_ast",
	"HE_alt",
	"HE_hepaB",
	"HE_HB",
	"HE_HCT",
	"HE_anem",
	"HE_BUN",
	"HE_crea",
	"HE_WBC",
	"HE_RBC",
	"HE_Uph",
	"HE_Unitr",
	"HE_Usg",
	"HE_Upro",
	"HE_Uglu",
	"HE_Uket",
	"HE_Ubil",
	"HE_Ubld",
	"HE_Uro",
	"O_PROS_U",
	"O_PROS_L",
	"OR1",
	"L_OUT_FQ",
	"L_BR_TO",
	"L_LN_TO",
	"L_DN_TO",
	"LK_LB_IT",
	"LK_LB_EF",
	"LK_EDU",
	"LF_SAFE",
	"N_DIET",
	"N_DIET_WHY",
	"N_DT_DS",
	"N_DUSUAL",
	"N_WAT_C",
	"N_DAY",
]

target_y = [
	"BP_PHQ_1",
	"BP_PHQ_2",
	"BP_PHQ_3",
	"BP_PHQ_4",
	"BP_PHQ_5",
	"BP_PHQ_6",
	"BP_PHQ_7",
	"BP_PHQ_8",
	"BP_PHQ_9",
	"mh_PHQ_S",
	"BP_GAD_1",
	"BP_GAD_2",
	"BP_GAD_3",
	"BP_GAD_4",
	"BP_GAD_5",
	"BP_GAD_6",
	"BP_GAD_7",
    
	"mh_GAD_S",
	"DF2_pr",
]

targets = target_4_8 + target_y

# %%
conditions = (df_origin["cardinal_number"] >= 4) \
            & (df_origin["age"] >= 19) \

df = df_origin[conditions][targets]

# %%
# save point
df.to_csv('../data/HN__4_8__19__selected.csv', index=False)
