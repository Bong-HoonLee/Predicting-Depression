# %% [markdown]
# ## 이스트소프트 WASSUP 정형데이터 프로젝트 7조 결과 보고서
#
# <br>
#
# #### 개요
# * 이 노트북 파일의 증거용 결과 지표는 프로그램 결과를 옮겨 적었으며 해당 모델 파라미터 등을 함께 기입한다
# * 실험에 사용된 모든 데이터는 [이곳](https://drive.google.com/drive/folders/1UjUa46Cx-X8-EDdWtWvQhg5gAbJgRlP3?usp=sharing)에 올려두었으며 프로그램 구동을 위해서 사용되는 csv 데이터들은 data 디렉토리에 위치하여야 동작하도록 되어있다
# * 추가 발표 자료 링크는 [이곳](https://www.canva.com/design/DAF2KTz0HZ0/ummrhRJLZqX-YvONhX2JvQ/edit?utm_content=DAF2KTz0HZ0&utm_campaign=designshare&utm_medium=link2&utm_source=sharebutton)
#
# <br>
#
# #### 실험결과 환경1(ANN)
# * ANN - model1
#   * config_path
#     * config/20231211_final/config_col_01_transformed.py
#
# config 세팅
# 1) Model=ANN
# 2) Model Params=ModuleList(
#  (0): Linear(in_features=208, out_features=32, bias=True)
#  (1): ReLU()
#  (2): Linear(in_features=32, out_features=1, bias=True)
#  (3): Sigmoid())
# 1) loss_function=BCELoss,
# 2) optimizer=Adam,
# 3) lr=0.0001
# 4) epochs=50
# 5) batch size = 32
#
# 실행 방법 <br>
# ./bin/train --mode=validate --config-dir=config/20231211_final
#
# 발표자료 첨부표 <br>
# ![발표자료첨부1](./ppt_ann_01.png)
#
# 실험 결과 <br>
# ![교차검증](./train_X_231211_final_col_01_transformed_history_20231212153248.png)
#
# 교차검증 로그
#
# |   trn_loss |   val_loss |   accuracy |    auroc |   f1score |   precision |   recall |
# |-----------:|-----------:|-----------:|---------:|----------:|------------:|---------:|
# |   0.41294  |   0.410281 |   0.790356 | 0.879678 |  0.776764 |    0.830437 | 0.729609 |
# |   0.410429 |   0.413992 |   0.790356 | 0.878491 |  0.773441 |    0.841506 | 0.715562 |
# |   0.413375 |   0.413222 |   0.797207 | 0.879902 |  0.78491  |    0.835576 | 0.740037 |
# |   0.410742 |   0.426334 |   0.783985 | 0.871559 |  0.777437 |    0.801741 | 0.754562 |
# |   0.409101 |   0.421192 |   0.787709 | 0.871976 |  0.774436 |    0.826087 | 0.728864 |
#
# ####
#
#
# <br>
#
# #### 실험결과 환경2(ANN)
# * ANN - model2
#   * config_path
#     * config/20231211_final/config_col_01_transformed.py
#
# config 세팅
# 1) Model=ANN
# 2) Model Params=ModuleList(
#  (0): Linear(in_features=208, out_features=2, bias=True)
#  (1): ReLU()
#  (2): Linear(in_features=2, out_features=1, bias=True)
#  (3): Sigmoid())
# 1) loss_function=BCELoss,
# 2) optimizer=Adam,
# 3) lr=0.0001
# 4) epochs=50
# 5) batch size = 32
#
# 실행 방법
# ./bin/train --mode=validate --config-dir=config/20231211_final
#
#
# 발표자료 첨부표 <br>
# ![발표자료첨부1](./ppt_ann_02.png)
#
# 실험 결과 <br>
# ![교차검증](./train_X_231211_final_col_01_transformed_node_count_2_history_20231212154231.png)
#
# 교차검증 로그 <br>
# |   trn_loss |   val_loss |   accuracy |    auroc |   f1score |   precision |   recall |
# |-----------:|-----------:|-----------:|---------:|----------:|------------:|---------:|
# |   0.432097 |   0.430215 |   0.789797 | 0.872646 |  0.776214 |    0.829661 | 0.729236 |
# |   0.431918 |   0.431738 |   0.789983 | 0.872539 |  0.779083 |    0.821901 | 0.740506 |
# |   0.43152  |   0.431409 |   0.79013  | 0.873273 |  0.778019 |    0.825669 | 0.735568 |
# |   0.428949 |   0.43932  |   0.783613 | 0.865917 |  0.7676   |    0.828942 | 0.714711 |
# |   0.428526 |   0.439671 |   0.783054 | 0.865062 |  0.769353 |    0.821217 | 0.72365  |
#
#
#
# <br>
#
# #### 실험결과 환경3(ANN)
# * ANN - Best model
#   * config_path
#     * config/20231211_final/config_col_01_transformed.py
#
# config 세팅
# 1) Model=ANN
# 2) Model Params=ModuleList(
#  (0): Linear(in_features=208, out_features=2, bias=True)
#  (1): ReLU()
#  (2): Linear(in_features=2, out_features=1, bias=True)
#  (3): Sigmoid())
# 1) loss_function=BCELoss,
# 2) optimizer=Adam,
# 3) lr=0.0001
# 4) epochs=50
# 5) batch size = 32
#
# 실행 방법
# ./bin/train --mode=validate --config-dir=config/20231211_final
#
# 실험 결과 <br>
# ![교차검증](./new_03_history_20231212160701.png)
#
# 발표자료 첨부표 <br>
# ![발표자료첨부1](./ppt_ann_03.png)
#
# 교차검증 로그 <br>
# |   trn_loss |   val_loss |   accuracy |    auroc |   f1score |   precision |   recall |
# |-----------:|-----------:|-----------:|---------:|----------:|------------:|---------:|
# |   0.417154 |   0.412956 |   0.79501  | 0.881761 |  0.774985 |    0.858696 | 0.706145 |
# |   0.41451  |   0.427776 |   0.789797 | 0.877481 |  0.786215 |    0.8      | 0.772897 |
# |   0.413693 |   0.415159 |   0.802048 | 0.882217 |  0.785383 |    0.857584 | 0.724395 |
# |   0.414312 |   0.425211 |   0.792179 | 0.873751 |  0.777601 |    0.836262 | 0.726629 |
# |   0.412025 |   0.428917 |   0.788827 | 0.871519 |  0.77721  |    0.822453 | 0.736685 |

# %%
import pandas as pd

df = pd.read_csv('./new_03_history_20231212160701.csv')
table = df.to_markdown(index=False)
print(table)
# Out:
# |   trn_loss |   val_loss |   accuracy |    auroc |   f1score |   precision |   recall |
# |-----------:|-----------:|-----------:|---------:|----------:|------------:|---------:|
# |   0.417154 |   0.412956 |   0.79501  | 0.881761 |  0.774985 |    0.858696 | 0.706145 |
# |   0.41451  |   0.427776 |   0.789797 | 0.877481 |  0.786215 |    0.8      | 0.772897 |
# |   0.413693 |   0.415159 |   0.802048 | 0.882217 |  0.785383 |    0.857584 | 0.724395 |
# |   0.414312 |   0.425211 |   0.792179 | 0.873751 |  0.777601 |    0.836262 | 0.726629 |
# |   0.412025 |   0.428917 |   0.788827 | 0.871519 |  0.77721  |    0.822453 | 0.736685 |
