# %% [markdown]
# ## 이스트소프트 WASSUP 정형데이터 프로젝트 7조 결과 보고서
#
# <br>
#
# #### 개요
# * 이 노트북 파일의 증거용 결과 지표는 프로그램 결과를 옮겨 적었으며 해당 모델 파라미터 등을 함께 기입한다
# * 실험에 사용된 모든 데이터는 [이곳](https://drive.google.com/drive/folders/1UjUa46Cx-X8-EDdWtWvQhg5gAbJgRlP3?usp=sharing)에 올려두었으며 프로그램 구동을 위해서 사용되는 csv 데이터들은 data 디렉토리에 위치하여야 동작하도록 되어있다
# * 추가 발표 자료 링크는 [이곳](https://www.canva.com/design/DAF2KTz0HZ0/ummrhRJLZqX-YvONhX2JvQ/edit?utm_content=DAF2KTz0HZ0&utm_campaign=designshare&utm_medium=link2&utm_source=sharebutton)
#
# <br>
#
# #### 실험결과 환경(ANN)
# * ANN - model1
#   * config_path
#     * config/20231211_final/config_col_01_transformed.py
#
# config 세팅
# 1) Model=ANN
# 2) Model Params=ModuleList(
#  (0): Linear(in_features=208, out_features=32, bias=True)
#  (1): ReLU()
#  (2): Linear(in_features=32, out_features=1, bias=True)
#  (3): Sigmoid())
# 1) loss_function=BCELoss,
# 2) optimizer=Adam,
# 3) lr=0.0001
# 4) epochs=50
# 5) batch size = 32
#
# 실행 방법
# ./bin/train --mode=validate --config-dir=config/20231211_final
#
# 실험 결과
# ![교차검증](./train_X_231211_final_col_01_transformed_history_20231212153248.png)
#
# 발표자료 첨부표
# ![발표자료첨부1](./ppt_ann_01.png)
#
# ####

# %%
import pandas as pd
df = pd.read_csv('../doc/20231212_report/train_X_231211_final_col_01_transformed_history_20231212153248.csv')
df
# Out:
#    trn_loss  val_loss  accuracy     auroc   f1score  precision    recall
# 0  0.412940  0.410281  0.790356  0.879678  0.776764   0.830437  0.729609
# 1  0.410429  0.413992  0.790356  0.878491  0.773441   0.841506  0.715562
# 2  0.413375  0.413222  0.797207  0.879902  0.784910   0.835576  0.740037
# 3  0.410742  0.426334  0.783985  0.871559  0.777437   0.801741  0.754562
# 4  0.409101  0.421192  0.787709  0.871976  0.774436   0.826087  0.728864

# %% [markdown]
# #### 실험결과 환경(ANN)
# * ANN - model2
#   * config_path
#     * config/20231211_final/config_col_01_transformed.py
#
# config 세팅
# 1) Model=ANN
# 2) Model Params=ModuleList(
#  (0): Linear(in_features=208, out_features=2, bias=True)
#  (1): ReLU()
#  (2): Linear(in_features=2, out_features=1, bias=True)
#  (3): Sigmoid())
# 1) loss_function=BCELoss,
# 2) optimizer=Adam,
# 3) lr=0.0001
# 4) epochs=50
# 5) batch size = 32
#
# 실행 방법
# ./bin/train --mode=validate --config-dir=config/20231211_final
#
# 실험 결과
# ![교차검증](./train_X_231211_final_col_01_transformed_node_count_2_history_20231212154231.png)
#
# 발표자료 첨부표
# ![발표자료첨부1](./ppt_ann_02.png)

# %%
import pandas as pd
df = pd.read_csv('../doc/20231212_report/train_X_231211_final_col_01_transformed_node_count_2_history_20231212154231.csv')
df
# Out:
#    trn_loss  val_loss  accuracy     auroc   f1score  precision    recall
# 0  0.432097  0.430215  0.789797  0.872646  0.776214   0.829661  0.729236
# 1  0.431918  0.431738  0.789983  0.872539  0.779083   0.821901  0.740506
# 2  0.431520  0.431409  0.790130  0.873273  0.778019   0.825669  0.735568
# 3  0.428949  0.439320  0.783613  0.865917  0.767600   0.828942  0.714711
# 4  0.428526  0.439671  0.783054  0.865062  0.769353   0.821217  0.723650
